# %%
#basemap
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.

# %%
combined=pd.read_csv("/Users/ellieculverhouse/Desktop/Project_1/Basin_data/makingown/Basin Counties - Sheet10.csv")
combined
# Out:
#      STATEFP  COUNTYFP  COUNTYNS  GEOID  State_Code  State_Name  County_Cod  \
# 0          8       109    198170   8109           8    Colorado         109
# 1         35         3    929108  35003          35  New Mexico           3
# 2         56        23   1605076  56023          56     Wyoming          23
# 3         56        13   1605072  56013          56     Wyoming          13
# 4          8       115    198173   8115           8    Colorado         115
# ..       ...       ...       ...    ...         ...         ...         ...
# 114        8         5    198118   8005           8    Colorado           5
# 115       56        35   1605082  56035          56     Wyoming          35
# 116       49        19   1448024  49019          49        Utah          19
# 117       35        61    933052  35061          35  New Mexico          61
# 118        8        49    198140   8049           8    Colorado          49
#
#              County_Nam  Total_Popu   Shape__Area  ...  Shape__Length.1  \
# 0       Saguache County        6108  3.256219e+09  ...     8.943215e+04
# 1         Catron County        3725  1.787428e+10  ...     3.361880e+05
# 2    Lincoln County, WY       18106  9.111559e+09  ...     2.493631e+05
# 3    Fremont County, WY       40123  9.132737e+08  ...     1.146127e+05
# 4       Sedgwick County        2379  6.519840e+08  ...     1.569276e+06
# ..                  ...         ...           ...  ...              ...
# 114     Arapahoe County      572003  4.292588e+08  ...              NaN
# 115     Sublette County       10247  2.134963e+10  ...              NaN
# 116    Grand County, UT        9225  1.581719e+10  ...              NaN
# 117     Valencia County       76569  1.522393e+09  ...              NaN
# 118    Grand County, CO       14843  8.269130e+09  ...              NaN
#
#      STATEFP.1    STATENS  GEOID.1      NAME.1  Shape__Area.1 Shape__Length.2  \
# 0         35.0   897535.0     35.0  New Mexico   4.644024e+11     2900120.524
# 1          6.0  1779778.0      6.0  California   6.718910e+11     5257953.465
# 2         49.0  1455989.0     49.0        Utah   3.682861e+11     2557182.577
# 3          8.0  1779779.0      8.0    Colorado   4.473110e+11     2708265.068
# 4         56.0  1779807.0     56.0     Wyoming   4.741976e+11     2777133.880
# ..         ...        ...      ...         ...            ...             ...
# 114        NaN        NaN      NaN         NaN            NaN             NaN
# 115        NaN        NaN      NaN         NaN            NaN             NaN
# 116        NaN        NaN      NaN         NaN            NaN             NaN
# 117        NaN        NaN      NaN         NaN            NaN             NaN
# 118        NaN        NaN      NaN         NaN            NaN             NaN
#
#      Allocation  Tribal_Water  Tribal_Percentage
# 0         0.844      0.652306            0.77287
# 1         4.400       0.01134            0.00256
# 2         1.725    ‭0.799886‬            0.46370
# 3         3.880      0.225448            0.06580
# 4         1.050             0            0.00000
# ..          ...           ...                ...
# 114         NaN           NaN                NaN
# 115         NaN           NaN                NaN
# 116         NaN           NaN                NaN
# 117         NaN           NaN                NaN
# 118         NaN           NaN                NaN
#
# [119 rows x 34 columns]
